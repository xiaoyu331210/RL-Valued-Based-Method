# %% [markdown]
# # Continuous Control
#
# ---
#
# In this notebook, you will learn how to use the Unity ML-Agents environment for the second project of the [Deep Reinforcement Learning Nanodegree](https://www.udacity.com/course/deep-reinforcement-learning-nanodegree--nd893) program.
#
# ### 1. Start the Environment
#
# We begin by importing the necessary packages.  If the code cell below returns an error, please revisit the project instructions to double-check that you have installed [Unity ML-Agents](https://github.com/Unity-Technologies/ml-agents/blob/master/docs/Installation.md) and [NumPy](http://www.numpy.org/).

# %%
from unityagents import UnityEnvironment
import numpy as np

# %% [markdown]
# Next, we will start the environment!  **_Before running the code cell below_**, change the `file_name` parameter to match the location of the Unity environment that you downloaded.
#
# - **Mac**: `"path/to/Reacher.app"`
# - **Windows** (x86): `"path/to/Reacher_Windows_x86/Reacher.exe"`
# - **Windows** (x86_64): `"path/to/Reacher_Windows_x86_64/Reacher.exe"`
# - **Linux** (x86): `"path/to/Reacher_Linux/Reacher.x86"`
# - **Linux** (x86_64): `"path/to/Reacher_Linux/Reacher.x86_64"`
# - **Linux** (x86, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86"`
# - **Linux** (x86_64, headless): `"path/to/Reacher_Linux_NoVis/Reacher.x86_64"`
#
# For instance, if you are using a Mac, then you downloaded `Reacher.app`.  If this file is in the same folder as the notebook, then the line below should appear as follows:
# ```
# env = UnityEnvironment(file_name="Reacher.app")
# ```

# %%
env = UnityEnvironment(file_name='Reacher.cpp')

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# In this environment, a double-jointed arm can move to target locations. A reward of `+0.1` is provided for each step that the agent's hand is in the goal location. Thus, the goal of your agent is to maintain its position at the target location for as many time steps as possible.
#
# The observation space consists of `33` variables corresponding to position, rotation, velocity, and angular velocities of the arm.  Each action is a vector with four numbers, corresponding to torque applicable to two joints.  Every entry in the action vector must be a number between `-1` and `1`.
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Once this cell is executed, you will watch the agent's performance, if it selects an action at random with each time step.  A window should pop up that allows you to observe the agent, as it moves through the environment.
#
# Of course, as part of the project, you'll have to change the code so that the agent is able to use its experience to gradually choose better actions when interacting with the environment!

# %%
env_info = env.reset(train_mode=False)[brain_name]     # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))

# %% [markdown]
# When finished, you can close the environment.

# %%
env.close()

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```

# %%
# Declare agent
import sys

# Add the subfolder to sys.path
sys.path.append('./reach_1_agent')

from unityagents import UnityEnvironment
import numpy as np
import importlib
import model
import agent
importlib.reload(agent)
importlib.reload(model)

env = UnityEnvironment(file_name="Reacher_Windows_x86_64/Reacher.exe")
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])


# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)
# declare the agent
discount_factor = 0.99
weight_decay = 0
agent = agent.ReachAgent(state_size, action_size, num_agents, discount_factor, weight_decay)
# Out:
# device cuda:0
# device cuda:0
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [ 0.00000000e+00 -4.00000000e+00  0.00000000e+00  1.00000000e+00
#  -0.00000000e+00 -0.00000000e+00 -4.37113883e-08  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00 -1.00000000e+01  0.00000000e+00
#   1.00000000e+00 -0.00000000e+00 -0.00000000e+00 -4.37113883e-08
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  5.75471878e+00 -1.00000000e+00
#   5.55726624e+00  0.00000000e+00  1.00000000e+00  0.00000000e+00
#  -1.68164849e-01]
# Number of agents: 20

# %%
# Function to train the network
from collections import deque
import torch
import matplotlib.pyplot as plt

def train(agent, env, num_agents, folder_path, n_episodes=2000, max_t=1000):

    all_rewards = []
    all_avg_rewards = []
    rewards_window = deque(maxlen=100)  # last 100 scores
    for i_episode in range(n_episodes):
        env_info = env.reset(train_mode=True)[brain_name]
        state = env_info.vector_observations[0 : num_agents]
        total_reward = np.zeros(num_agents)
        agent.reset()
        for t in range(max_t):
            # get action from the agent based on the curernt states
            action = agent.act(state)
            # update the env based on the action
            env_info = env.step(action)[brain_name]
            next_state = env_info.vector_observations[0 : num_agents]
            reward = env_info.rewards[0 : num_agents]
            done = env_info.local_done[0 : num_agents]
            # update the agent
            agent.step(state, action, reward, next_state, done)
            # update for the next iteration
            state = next_state
            total_reward += reward
            # the episode reachs the end, so need to start a new episode
            if np.any( done[0 : num_agents] ): 
                print("reached end at t: ", t)
                break
        all_rewards.append(np.mean(total_reward))
        rewards_window.append(np.mean(total_reward))
        all_avg_rewards.append(np.mean(rewards_window))
        print('Episode {}\tAverage Score: {:.2f}\t Total Score: {:.2f}'.format(i_episode, np.mean(rewards_window), np.mean(total_reward)))
        if i_episode % 100 == 0:
            print('Episode {}\tAverage Score: {:.2f}\t Total Score: {:.2f}'.format(i_episode, np.mean(rewards_window), np.mean(total_reward)))
        if np.mean(rewards_window)>=32.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(rewards_window)))
            break
        if i_episode % 200 == 0:
            torch.save(agent.actor.state_dict(), folder_path + 'reacher_actor_checkpoint_max_t_1000_ep_' + str(i_episode) + '.pth')
            torch.save(agent.actor_target.state_dict(), folder_path + 'reacher_actor_target_checkpoint_max_t_1000_ep_' + str(i_episode) + '.pth')
            torch.save(agent.critic.state_dict(), folder_path + 'reacher_critic_checkpoint_max_t_1000_ep_' + str(i_episode) + '.pth')
            torch.save(agent.critic_target.state_dict(), folder_path + 'reacher_critic_target_checkpoint_max_t_1000_ep_' + str(i_episode) + '.pth')
    
    return all_rewards, all_avg_rewards

folder_path = "weights/"
scores, avg_scores = train(agent, env, num_agents, folder_path, 2000, 1000)
env.close()

# save the trained weight
torch.save(agent.actor.state_dict(), folder_path + 'reacher_actor_checkpoint_max_t_1000.pth')
torch.save(agent.actor_target.state_dict(), folder_path + 'reacher_actor_target_checkpoint_max_t_1000.pth')
torch.save(agent.critic.state_dict(), folder_path + 'reacher_critic_checkpoint_max_t_1000.pth')
torch.save(agent.critic_target.state_dict(), folder_path + 'reacher_critic_target_checkpoint_max_t_1000.pth')

# plot the score distribution
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), avg_scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 0	Average Score: 0.85	 Total Score: 0.85
# Episode 0	Average Score: 0.85	 Total Score: 0.85
# Episode 1	Average Score: 0.78	 Total Score: 0.70
# Episode 2	Average Score: 0.78	 Total Score: 0.79
# Episode 3	Average Score: 0.76	 Total Score: 0.70
# Episode 4	Average Score: 0.80	 Total Score: 0.96
# Episode 5	Average Score: 0.80	 Total Score: 0.80
# Episode 6	Average Score: 0.78	 Total Score: 0.66
# Episode 7	Average Score: 0.77	 Total Score: 0.69
# Episode 8	Average Score: 0.74	 Total Score: 0.54
# Episode 9	Average Score: 0.73	 Total Score: 0.64
# Episode 10	Average Score: 0.72	 Total Score: 0.63
# Episode 11	Average Score: 0.73	 Total Score: 0.80
# Episode 12	Average Score: 0.77	 Total Score: 1.26
# Episode 13	Average Score: 0.82	 Total Score: 1.39
# Episode 14	Average Score: 0.87	 Total Score: 1.62
# Episode 15	Average Score: 0.91	 Total Score: 1.45
# Episode 16	Average Score: 0.94	 Total Score: 1.55
# Episode 17	Average Score: 0.96	 Total Score: 1.32
# Episode 18	Average Score: 0.99	 Total Score: 1.43
# Episode 19	Average Score: 1.02	 Total Score: 1.54
# Episode 20	Average Score: 1.08	 Total Score: 2.28
# Episode 21	Average Score: 1.11	 Total Score: 1.70
# Episode 22	Average Score: 1.14	 Total Score: 1.99
# Episode 23	Average Score: 1.18	 Total Score: 1.89
# Episode 24	Average Score: 1.20	 Total Score: 1.87
# Episode 25	Average Score: 1.24	 Total Score: 2.20
# Episode 26	Average Score: 1.29	 Total Score: 2.56
# Episode 27	Average Score: 1.34	 Total Score: 2.62
# Episode 28	Average Score: 1.37	 Total Score: 2.38
# Episode 29	Average Score: 1.41	 Total Score: 2.55
# Episode 30	Average Score: 1.47	 Total Score: 3.16
# Episode 31	Average Score: 1.55	 Total Score: 4.06
# Episode 32	Average Score: 1.65	 Total Score: 4.67
# Episode 33	Average Score: 1.72	 Total Score: 4.23
# Episode 34	Average Score: 1.80	 Total Score: 4.37
# Episode 35	Average Score: 1.87	 Total Score: 4.30
# Episode 36	Average Score: 1.96	 Total Score: 5.25
# Episode 37	Average Score: 2.03	 Total Score: 4.72
# Episode 38	Average Score: 2.12	 Total Score: 5.33
# Episode 39	Average Score: 2.20	 Total Score: 5.42
# Episode 40	Average Score: 2.26	 Total Score: 4.54
# Episode 41	Average Score: 2.34	 Total Score: 5.89
# Episode 42	Average Score: 2.47	 Total Score: 7.72
# Episode 43	Average Score: 2.54	 Total Score: 5.57
# Episode 44	Average Score: 2.65	 Total Score: 7.48
# Episode 45	Average Score: 2.75	 Total Score: 7.46
# Episode 46	Average Score: 2.87	 Total Score: 8.21
# Episode 47	Average Score: 2.96	 Total Score: 7.07
# Episode 48	Average Score: 3.05	 Total Score: 7.66
# Episode 49	Average Score: 3.18	 Total Score: 9.24
# Episode 50	Average Score: 3.29	 Total Score: 9.19
# Episode 51	Average Score: 3.40	 Total Score: 8.71
# Episode 52	Average Score: 3.51	 Total Score: 9.24
# Episode 53	Average Score: 3.64	 Total Score: 10.75
# Episode 54	Average Score: 3.79	 Total Score: 11.93
# Episode 55	Average Score: 3.93	 Total Score: 11.75
# Episode 56	Average Score: 4.06	 Total Score: 11.04
# Episode 57	Average Score: 4.18	 Total Score: 11.04
# Episode 58	Average Score: 4.31	 Total Score: 12.14
# Episode 59	Average Score: 4.48	 Total Score: 14.26
# Episode 60	Average Score: 4.67	 Total Score: 16.20
# Episode 61	Average Score: 4.83	 Total Score: 14.63
# Episode 62	Average Score: 5.00	 Total Score: 15.59
# Episode 63	Average Score: 5.17	 Total Score: 15.76
# Episode 64	Average Score: 5.35	 Total Score: 16.48
# Episode 65	Average Score: 5.52	 Total Score: 16.75
# Episode 66	Average Score: 5.69	 Total Score: 17.14
# Episode 67	Average Score: 5.86	 Total Score: 17.39
# Episode 68	Average Score: 6.06	 Total Score: 19.37
# Episode 69	Average Score: 6.22	 Total Score: 17.24
# Episode 70	Average Score: 6.47	 Total Score: 23.93
# Episode 71	Average Score: 6.70	 Total Score: 23.13
# Episode 72	Average Score: 6.88	 Total Score: 20.02
# Episode 73	Average Score: 7.07	 Total Score: 20.77
# Episode 74	Average Score: 7.26	 Total Score: 21.33
# Episode 75	Average Score: 7.46	 Total Score: 22.28
# Episode 76	Average Score: 7.67	 Total Score: 23.73
# Episode 77	Average Score: 7.88	 Total Score: 23.72
# Episode 78	Average Score: 8.08	 Total Score: 23.70
# Episode 79	Average Score: 8.32	 Total Score: 27.68
# Episode 80	Average Score: 8.58	 Total Score: 29.38
# Episode 81	Average Score: 8.83	 Total Score: 29.04
# Episode 82	Average Score: 9.07	 Total Score: 29.08
# Episode 83	Average Score: 9.32	 Total Score: 29.33
# Episode 84	Average Score: 9.56	 Total Score: 30.05
# Episode 85	Average Score: 9.80	 Total Score: 30.18
# Episode 86	Average Score: 10.06	 Total Score: 32.69
# Episode 87	Average Score: 10.31	 Total Score: 31.73
# Episode 88	Average Score: 10.54	 Total Score: 31.28
# Episode 89	Average Score: 10.78	 Total Score: 31.36
# Episode 90	Average Score: 11.02	 Total Score: 33.02
# Episode 91	Average Score: 11.26	 Total Score: 33.10
# Episode 92	Average Score: 11.51	 Total Score: 34.71
# Episode 93	Average Score: 11.76	 Total Score: 34.94
# Episode 94	Average Score: 12.01	 Total Score: 35.62
# Episode 95	Average Score: 12.27	 Total Score: 36.36
# Episode 96	Average Score: 12.51	 Total Score: 35.84
# Episode 97	Average Score: 12.75	 Total Score: 35.69
# Episode 98	Average Score: 12.99	 Total Score: 36.73
# Episode 99	Average Score: 13.22	 Total Score: 36.52
# Episode 100	Average Score: 13.58	 Total Score: 36.50
# Episode 100	Average Score: 13.58	 Total Score: 36.50
# Episode 101	Average Score: 13.93	 Total Score: 35.72
# Episode 102	Average Score: 14.29	 Total Score: 36.68
# Episode 103	Average Score: 14.66	 Total Score: 37.73
# Episode 104	Average Score: 15.02	 Total Score: 37.33
# Episode 105	Average Score: 15.39	 Total Score: 37.66
# Episode 106	Average Score: 15.76	 Total Score: 37.38
# Episode 107	Average Score: 16.13	 Total Score: 37.99
# Episode 108	Average Score: 16.51	 Total Score: 38.52
# Episode 109	Average Score: 16.88	 Total Score: 37.59
# Episode 110	Average Score: 17.25	 Total Score: 37.69
# Episode 111	Average Score: 17.62	 Total Score: 38.03
# Episode 112	Average Score: 17.99	 Total Score: 37.99
# Episode 113	Average Score: 18.35	 Total Score: 37.70
# Episode 114	Average Score: 18.72	 Total Score: 37.86
# Episode 115	Average Score: 19.09	 Total Score: 38.35
# Episode 116	Average Score: 19.45	 Total Score: 38.22
# Episode 117	Average Score: 19.82	 Total Score: 38.27
# Episode 118	Average Score: 20.19	 Total Score: 38.16
# Episode 119	Average Score: 20.56	 Total Score: 38.63
# Episode 120	Average Score: 20.92	 Total Score: 37.86
# Episode 121	Average Score: 21.28	 Total Score: 38.38
# Episode 122	Average Score: 21.64	 Total Score: 38.05
# Episode 123	Average Score: 22.00	 Total Score: 37.78
# Episode 124	Average Score: 22.36	 Total Score: 38.05
# Episode 125	Average Score: 22.72	 Total Score: 38.17
# Episode 126	Average Score: 23.08	 Total Score: 38.65
# Episode 127	Average Score: 23.44	 Total Score: 38.25
# Episode 128	Average Score: 23.80	 Total Score: 38.36
# Episode 129	Average Score: 24.16	 Total Score: 38.45
# Episode 130	Average Score: 24.51	 Total Score: 38.29
# Episode 131	Average Score: 24.85	 Total Score: 38.39
# Episode 132	Average Score: 25.19	 Total Score: 38.75
# Episode 133	Average Score: 25.54	 Total Score: 38.42
# Episode 134	Average Score: 25.88	 Total Score: 38.50
# Episode 135	Average Score: 26.22	 Total Score: 38.39
# Episode 136	Average Score: 26.55	 Total Score: 38.74
# Episode 137	Average Score: 26.89	 Total Score: 38.34
# Episode 138	Average Score: 27.22	 Total Score: 38.79
# Episode 139	Average Score: 27.55	 Total Score: 38.37
# Episode 140	Average Score: 27.89	 Total Score: 38.09
# Episode 141	Average Score: 28.21	 Total Score: 38.32
# Episode 142	Average Score: 28.52	 Total Score: 38.70
# Episode 143	Average Score: 28.85	 Total Score: 38.35
# Episode 144	Average Score: 29.16	 Total Score: 38.02
# Episode 145	Average Score: 29.46	 Total Score: 38.06
# Episode 146	Average Score: 29.76	 Total Score: 37.70
# Episode 147	Average Score: 30.07	 Total Score: 38.21
# Episode 148	Average Score: 30.37	 Total Score: 38.23
# Episode 149	Average Score: 30.66	 Total Score: 37.87
# Episode 150	Average Score: 30.95	 Total Score: 38.10
# Episode 151	Average Score: 31.24	 Total Score: 37.98
# Episode 152	Average Score: 31.53	 Total Score: 38.00
# Episode 153	Average Score: 31.80	 Total Score: 38.09
# Episode 154	Average Score: 32.07	 Total Score: 38.13
# Episode 155	Average Score: 32.33	 Total Score: 37.88
# Episode 156	Average Score: 32.59	 Total Score: 37.52
# Episode 157	Average Score: 32.86	 Total Score: 37.76
# Episode 158	Average Score: 33.11	 Total Score: 37.44
# Episode 159	Average Score: 33.35	 Total Score: 37.65
# Episode 160	Average Score: 33.56	 Total Score: 37.71
# Episode 161	Average Score: 33.79	 Total Score: 37.92
# Episode 162	Average Score: 34.01	 Total Score: 37.32
# Episode 163	Average Score: 34.23	 Total Score: 37.73
# Episode 164	Average Score: 34.45	 Total Score: 38.06
# Episode 165	Average Score: 34.66	 Total Score: 38.03
# Episode 166	Average Score: 34.86	 Total Score: 37.22
# Episode 167	Average Score: 35.05	 Total Score: 36.84
#
# Environment solved in 67 episodes!	Average Score: 35.05
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
